# %% [markdown]
# # Queries in the SQLite Database by using PANDAS SQL in the Data frame-[Phase2]

# %%
import sqlite3
import pandas as pd

# %%
imdb=pd.read_csv('Top Rated 50 Movies Data from IMDB11.csv')

# %%
imdb.head()
# Out:
#    Unnamed: 0                                         Movie_name
# 0           0                                    The Dark Knight  \
# 1           1      The Lord of the Rings: The Return of the King
# 2           2                                          Inception
# 3           3  The Lord of the Rings: The Fellowship of the Ring
# 4           4              The Lord of the Rings: The Two Towers
#
#                     Star1                  Star2             Star3
# 0          Christian Bale           Heath Ledger     Aaron Eckhart  \
# 1             Elijah Wood        Viggo Mortensen      Ian McKellen
# 2       Leonardo DiCaprio   Joseph Gordon-Levitt       Elliot Page
# 3             Elijah Wood           Ian McKellen     Orlando Bloom
# 4             Elijah Wood           Ian McKellen   Viggo Mortensen
#
#             Star4      Votes  Genre1      Genre2              Genre3
# 0   Michael Caine  2,717,319  Action       Crime   Drama              \
# ...

# %%
imdb.columns
# Out:
# Index(['Unnamed: 0', 'Movie_name', 'Star1', 'Star2', 'Star3', 'Star4', 'Votes',
#        'Genre1', 'Genre2', 'Genre3', 'Gross_collection', 'Popularity',
#        'Certificates'],
#       dtype='object')

# %% [markdown]
# # SQLite3 Queries

# %%
from pandasql import sqldf

# %%
conn=sqlite3.connect('myimdbtable.db')

# %%
imdb.to_sql(name="imdbmovies",con=conn,if_exists='replace',index=False)
# Out:
# 50

# %%
conn.commit()

# %%
df_imdb = pd.read_sql_query('select * from imdbmovies', conn)

# %%
df_imdb
# Out:
#     Unnamed: 0                                         Movie_name
# 0            0                                    The Dark Knight  \
# 1            1      The Lord of the Rings: The Return of the King
# 2            2                                          Inception
# 3            3  The Lord of the Rings: The Fellowship of the Ring
# 4            4              The Lord of the Rings: The Two Towers
# 5            5                                         The Matrix
# 6            6     Star Wars: Episode V - The Empire Strikes Back
# 7            7                                    Soorarai Pottru
# 8            8                                          Star Wars
# 9            9                         Terminator 2: Judgment Day
# 10          10                               Shichinin no samurai
# 11          11                                            Seppuku
# 12          12                                         Sita Ramam
# ...

# %% [markdown]
# # Q.1) Display all movie names with star Arnold Schwarzenegger in ascending order.

# %%
# How to change the order of records(Increasing or decreasing)
query1 = "SELECT * FROM df_imdb ORDER BY Movie_name desc"
sqldf(query1,globals())
# Out:
#     Unnamed: 0                                         Movie_name
# 0           49                                            Yôjinbô  \
# 1           47                                       Vikram Vedha
# 2           32                                             Vikram
# 3           43                                     V for Vendetta
# 4           24                                  Top Gun: Maverick
# 5            5                                         The Matrix
# 6            4              The Lord of the Rings: The Two Towers
# 7            1      The Lord of the Rings: The Return of the King
# 8            3  The Lord of the Rings: The Fellowship of the Ring
# 9           20                              The Dark Knight Rises
# 10           0                                    The Dark Knight
# 11           9                         Terminator 2: Judgment Day
# 12          26         Star Wars: Episode VI - Return of the Jedi
# ...

# %%
#select the movie name,and star1 name

query ="""SELECT Movie_name,Star1 FROM df_imdb LIMIT 15"""
name_star1 = sqldf(query)
name_star1
# Out:
#                                            Movie_name
# 0                                     The Dark Knight  \
# 1       The Lord of the Rings: The Return of the King
# 2                                           Inception
# 3   The Lord of the Rings: The Fellowship of the Ring
# 4               The Lord of the Rings: The Two Towers
# 5                                          The Matrix
# 6      Star Wars: Episode V - The Empire Strikes Back
# 7                                     Soorarai Pottru
# 8                                           Star Wars
# 9                          Terminator 2: Judgment Day
# 10                               Shichinin no samurai
# 11                                            Seppuku
# 12                                         Sita Ramam
# 13                                               Léon
# 14                                          Gladiator
#
#                          Star1
# 0               Christian Bale
# 1                  Elijah Wood
# ...

# %%
#Order the results by movie name with star in descending order
query1 = "SELECT * FROM df_imdb WHERE Star1='Arnold Schwarzenegger' ORDER BY Movie_name DESC"
sqldf(query1,globals())
# Out:
# Empty DataFrame
# Columns: [Unnamed: 0, Movie_name, Star1, Star2, Star3, Star4, Votes, Genre1, Genre2, Genre3, Gross_collection, Popularity, Certificates]
# Index: []

# %%
#Order the results by movie name with star in descending order
query1 = "SELECT * FROM df_imdb WHERE star1='Arnold Schwarzenegger'"
sqldf(query1,globals())
# Out:
# Empty DataFrame
# Columns: [Unnamed: 0, Movie_name, Star1, Star2, Star3, Star4, Votes, Genre1, Genre2, Genre3, Gross_collection, Popularity, Certificates]
# Index: []

# %%
#select the movie name,and star1 name

query ="""SELECT Movie_name FROM df_imdb WHERE Star1='Arnold Schwarzenegger' ORDER BY Movie_name ASC """

#Execute the query
name_star1 = sqldf(query)
name_star1
# Out:
# Empty DataFrame
# Columns: [Movie_name]
# Index: []

# %%
#Order the results by movie name with star in descending order
query1 = "SELECT * FROM df_imdb WHERE Star1='Christian Bale' ORDER BY Movie_name DESC"
sqldf(query1,globals())
# Out:
# Empty DataFrame
# Columns: [Unnamed: 0, Movie_name, Star1, Star2, Star3, Star4, Votes, Genre1, Genre2, Genre3, Gross_collection, Popularity, Certificates]
# Index: []

# %%
query = """SELECT * FROM df_imdb WHERE Star1 = 'Arnold Schwarzenegger'LIMIT 10 """

#Execute the query
name_star1 = sqldf(query)
name_star1
# Out:
# Empty DataFrame
# Columns: [Unnamed: 0, Movie_name, Star1, Star2, Star3, Star4, Votes, Genre1, Genre2, Genre3, Gross_collection, Popularity, Certificates]
# Index: []

# %%
#select the Directors names from movies

query1 = "SELECT * FROM df_imdb WHERE Star1 == 'Arnold Schwarzenegger' AND Star2 == 'Christian Bale'"
name_stars = sqldf(query)
name_stars
# Out:
# Empty DataFrame
# Columns: [Unnamed: 0, Movie_name, Star1, Star2, Star3, Star4, Votes, Genre1, Genre2, Genre3, Gross_collection, Popularity, Certificates]
# Index: []

# %%
#select the Movies Names with star names 

query1 = "SELECT * FROM df_imdb WHERE Star1 LIKE 'Arnold Schwarzenegger%'"
name_stars = sqldf(query1)
name_stars
# Out:
# Empty DataFrame
# Columns: [Unnamed: 0, Movie_name, Star1, Star2, Star3, Star4, Votes, Genre1, Genre2, Genre3, Gross_collection, Popularity, Certificates]
# Index: []

# %% [markdown]
# # Q.2) Display all details of the movie with the highest number of votes.

# %%
Query2 = "SELECT MAX(Votes) FROM df_imdb"
sqldf(Query2,globals())
# Out:
#   MAX(Votes)
# 0     99,318

# %%
Query2 = "SELECT MIN(Votes) FROM df_imdb"
sqldf(Query2,globals())
# Out:
#   MIN(Votes)
# 0  1,013,513

# %% [markdown]
# # Q.3) Display movie names with gross collections in descending order.

# %%
# How to change the order of records(Increasing or decreasing)
query3 = "SELECT * FROM df_imdb ORDER BY Gross_collection desc"
sqldf(query3,globals())
# Out:
#     Unnamed: 0                                         Movie_name
# 0            7                                    Soorarai Pottru  \
# 1           11                                            Seppuku
# 2           12                                         Sita Ramam
# 3           22                                             Kaithi
# 4           23                                             Asuran
# 5           29                                            Kantara
# 6           32                                             Vikram
# 7           33                                           Ratsasan
# 8           34                                          Shershaah
# 9           35                     Guardians of the Galaxy Vol. 3
# 10          46                                 Gangs of Wasseypur
# 11          47                                       Vikram Vedha
# 12          49                                            Yôjinbô
# ...

# %%
# How to change the order of records(Increasing or decreasing)
query3 = "SELECT * FROM df_imdb ORDER BY Gross_collection asc"
sqldf(query3,globals())
# Out:
#     Unnamed: 0                                         Movie_name
# 0           10                               Shichinin no samurai  \
# 1           19                                           Oldeuboi
# 2           30                                             Dangal
# 3           28                                 North by Northwest
# 4           39                                               1917
# 5            5                                         The Matrix
# 6           14                                          Gladiator
# 7           13                                               Léon
# 8           15                  Spider-Man: Into the Spider-Verse
# 9           38                 Indiana Jones and the Last Crusade
# 10          27                                      Mononoke-hime
# 11          48                        Baahubali 2: The Conclusion
# 12           9                         Terminator 2: Judgment Day
# ...

# %% [markdown]
# # Q.4) Display the gross collection of movies with the star Arnold.

# %%
query4 = "SELECT Movie_name FROM df_imdb WHERE Movie_Name LIKE 'S%' AND Popularity>7"
sqldf(query4,globals())
# Out:
#                                        Movie_name
# 0  Star Wars: Episode V - The Empire Strikes Back
# 1                                 Soorarai Pottru
# 2                                       Star Wars
# 3                            Shichinin no samurai
# 4                                         Seppuku
# 5                                      Sita Ramam
# 6               Spider-Man: Into the Spider-Verse
# 7      Star Wars: Episode VI - Return of the Jedi
# 8                                       Shershaah
# 9                         Spider-Man: No Way Home

# %%
query4 = "SELECT Gross_collection FROM df_imdb WHERE Gross_collection LIKE 'A%'"
sqldf(query4,globals())
# Out:
# Empty DataFrame
# Columns: [Gross_collection]
# Index: []

# %%
query4 = "SELECT * FROM df_imdb WHERE Star1 == 'Arnold' "
sqldf(query4,globals())
# Out:
# Empty DataFrame
# Columns: [Unnamed: 0, Movie_name, Star1, Star2, Star3, Star4, Votes, Genre1, Genre2, Genre3, Gross_collection, Popularity, Certificates]
# Index: []

# %%
query4 = "SELECT Movie_name,Gross_collection FROM df_imdb ORDER BY Gross_collection DESC LIMIT 20"
sqldf(query4,globals())
# Out:
#                         Movie_name Gross_collection
# 0                  Soorarai Pottru           ******
# 1                          Seppuku           ******
# 2                       Sita Ramam           ******
# 3                           Kaithi           ******
# 4                           Asuran           ******
# 5                          Kantara           ******
# 6                           Vikram           ******
# 7                         Ratsasan           ******
# 8                        Shershaah           ******
# 9   Guardians of the Galaxy Vol. 3           ******
# 10              Gangs of Wasseypur           ******
# 11                    Vikram Vedha           ******
# 12                         Yôjinbô           ******
# 13               Avengers: Endgame         $858.37M
# 14                          Aliens          $85.16M
# 15                        Die Hard          $83.01M
# 16         Spider-Man: No Way Home         $804.75M
# ...

# %%
query4 = "SELECT Movie_name,Star1,Gross_collection FROM df_imdb ORDER BY Gross_collection DESC LIMIT 20"
sqldf(query4,globals())
# Out:
#                         Movie_name                   Star1 Gross_collection
# 0                  Soorarai Pottru                  Suriya           ******
# 1                          Seppuku         Tatsuya Nakadai           ******
# 2                       Sita Ramam         Dulquer Salmaan           ******
# 3                           Kaithi                  Karthi           ******
# 4                           Asuran                 Dhanush           ******
# 5                          Kantara           Rishab Shetty           ******
# 6                           Vikram            Kamal Haasan           ******
# 7                         Ratsasan           Vishnu Vishal           ******
# 8                        Shershaah       Sidharth Malhotra           ******
# 9   Guardians of the Galaxy Vol. 3             Chris Pratt           ******
# 10              Gangs of Wasseypur          Manoj Bajpayee           ******
# ...

# %%
query4 = "SELECT Movie_name,Star1,Gross_collection FROM df_imdb WHERE Star1= 'Arnold'OR Popularity>=7"
sqldf(query4,globals())
# Out:
#                                            Movie_name
# 0                                     The Dark Knight  \
# 1       The Lord of the Rings: The Return of the King
# 2                                           Inception
# 3   The Lord of the Rings: The Fellowship of the Ring
# 4               The Lord of the Rings: The Two Towers
# 5                                          The Matrix
# 6      Star Wars: Episode V - The Empire Strikes Back
# 7                                     Soorarai Pottru
# 8                                           Star Wars
# 9                          Terminator 2: Judgment Day
# 10                               Shichinin no samurai
# 11                                            Seppuku
# 12                                         Sita Ramam
# 13                                               Léon
# 14                                          Gladiator
# 15                  Spider-Man: Into the Spider-Verse
# ...

# %% [markdown]
# # Q.5) Display all details of movies with comedy and action genres.

# %%
query5 = "SELECT * FROM df_imdb WHERE Genre1== 'Comedy' OR Genre2 == 'Action'"
sqldf(query5,globals())
# Out:
# Empty DataFrame
# Columns: [Unnamed: 0, Movie_name, Star1, Star2, Star3, Star4, Votes, Genre1, Genre2, Genre3, Gross_collection, Popularity, Certificates]
# Index: []

# %%
query5 = "SELECT * FROM df_imdb WHERE Genre1== 'Action' OR Genre2 == 'Comedy'"
sqldf(query5,globals())
# Out:
#     Unnamed: 0                                         Movie_name
# 0            0                                    The Dark Knight  \
# 1            1      The Lord of the Rings: The Return of the King
# 2            2                                          Inception
# 3            3  The Lord of the Rings: The Fellowship of the Ring
# 4            4              The Lord of the Rings: The Two Towers
# 5            5                                         The Matrix
# 6            6     Star Wars: Episode V - The Empire Strikes Back
# 7            7                                    Soorarai Pottru
# 8            8                                          Star Wars
# 9            9                         Terminator 2: Judgment Day
# 10          16                                  Avengers: Endgame
# 11          17                            Raiders of the Lost Ark
# 12          18                             Avengers: Infinity War
# ...

# %%
query5 = "SELECT Movie_name,Genre1,Genre2 FROM df_imdb WHERE Genre1== 'Action' OR Genre2 == 'Comedy'"
sqldf(query5,globals())
# Out:
#                                            Movie_name  Genre1
# 0                                     The Dark Knight  Action  \
# 1       The Lord of the Rings: The Return of the King  Action
# 2                                           Inception  Action
# 3   The Lord of the Rings: The Fellowship of the Ring  Action
# 4               The Lord of the Rings: The Two Towers  Action
# 5                                          The Matrix  Action
# 6      Star Wars: Episode V - The Empire Strikes Back  Action
# 7                                     Soorarai Pottru  Action
# 8                                           Star Wars  Action
# 9                          Terminator 2: Judgment Day  Action
# 10                                  Avengers: Endgame  Action
# 11                            Raiders of the Lost Ark  Action
# 12                             Avengers: Infinity War  Action
# 13                                           Oldeuboi  Action
# ...

# %%
query6 = "SELECT Movie_name,Genre1,Genre2 FROM df_imdb WHERE Genre1== 'Action' AND Genre2 == 'Comedy'"
sqldf(query6,globals())
# Out:
# Empty DataFrame
# Columns: [Movie_name, Genre1, Genre2]
# Index: []

# %%
query5 = "SELECT Movie_name,Genre1,Genre2 FROM df_imdb WHERE Genre1== 'Action' OR Genre2 == 'Adventure'"
sqldf(query5,globals())
# Out:
#                                            Movie_name  Genre1
# 0                                     The Dark Knight  Action  \
# 1       The Lord of the Rings: The Return of the King  Action
# 2                                           Inception  Action
# 3   The Lord of the Rings: The Fellowship of the Ring  Action
# 4               The Lord of the Rings: The Two Towers  Action
# 5                                          The Matrix  Action
# 6      Star Wars: Episode V - The Empire Strikes Back  Action
# 7                                     Soorarai Pottru  Action
# 8                                           Star Wars  Action
# 9                          Terminator 2: Judgment Day  Action
# 10                                  Avengers: Endgame  Action
# 11                            Raiders of the Lost Ark  Action
# 12                             Avengers: Infinity War  Action
# 13                                           Oldeuboi  Action
# ...

# %% [markdown]
# # **********DONE********
